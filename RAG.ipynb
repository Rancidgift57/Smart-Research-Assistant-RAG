# %%
pip install langchain langchain-community langchain-openai langchain-google-genai chromadb pypdf unstructured sentence-transformers streamlit fastapi uvicorn
# Out:
# Requirement already satisfied: langchain in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-community in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-google-genai in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (3.2.0)
# Requirement already satisfied: chromadb in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (1.3.5)
# Requirement already satisfied: pypdf in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (6.5.0)
# Requirement already satisfied: unstructured in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (0.18.21)
# Requirement already satisfied: sentence-transformers in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (5.2.0)
# Requirement already satisfied: streamlit in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (1.52.2)
# Requirement already satisfied: fastapi in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (0.116.1)
# Requirement already satisfied: uvicorn in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (0.38.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.53)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-genai) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (6.33.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.62.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: python-magic in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (6.0.2)
# Requirement already satisfied: nltk in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (4.14.2)
# Requirement already satisfied: emoji in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: python-iso639 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (2025.11.16)
# Requirement already satisfied: langdetect in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: unstructured-client in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (0.42.6)
# Requirement already satisfied: wrapt in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (1.14.2)
# Requirement already satisfied: psutil in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (7.1.3)
# Requirement already satisfied: python-oxmsg in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.56.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.16.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: filelock in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.7.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (22.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.14.0)
# Requirement already satisfied: colorama in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from fastapi) (0.47.2)
# Requirement already satisfied: pyproject_hooks in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->unstructured) (2.8)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: webencodings in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: joblib in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from nltk->unstructured) (1.5.1)
# Requirement already satisfied: olefile in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from unstructured-client->unstructured) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"

# %%
import google.generativeai as genai
from PIL import Image

genai.configure(api_key="")
model = genai.GenerativeModel('gemini-1.5-pro')

def get_answer_from_visual_context(page_image_path, user_query):
    img = Image.open(page_image_path)
    
    # The prompt instructs the model to look at the visual elements specifically
    prompt = f"""
    You are an expert document analyst. Use the provided image of the document page 
    to answer the question: {user_query}. 
    If there are charts, tables, or diagrams, analyze them carefully.
    """
    
    response = model.generate_content([prompt, img])
    return response.text

# %%
pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.7-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.7-cp310-abi3-win_amd64.whl (18.4 MB)
#    ---------------------------------------- 0.0/18.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/18.4 MB 7.4 MB/s eta 0:00:03
#    ------ --------------------------------- 3.1/18.4 MB 8.4 MB/s eta 0:00:02
#    --------- ------------------------------ 4.2/18.4 MB 7.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.7/18.4 MB 5.9 MB/s eta 0:00:03
#    ------------ --------------------------- 5.8/18.4 MB 5.7 MB/s eta 0:00:03
#    ------------- -------------------------- 6.3/18.4 MB 5.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 7.6/18.4 MB 5.2 MB/s eta 0:00:03
#    -------------------- ------------------- 9.4/18.4 MB 5.7 MB/s eta 0:00:02
#    ------------------------- -------------- 11.5/18.4 MB 6.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 13.6/18.4 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 15.5/18.4 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 17.3/18.4 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 18.4/18.4 MB 7.1 MB/s  0:00:02
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz  # PyMuPDF

def pdf_to_images(pdf_path):
    doc = fitz.open(pdf_path)
    image_paths = []
    for i in range(len(doc)):
        page = doc.load_page(i)
        pix = page.get_pixmap()
        path = f"page_{i}.png"
        pix.save(path)
        image_paths.append(path)
    return image_paths

# %%
client = chromadb.Client()

try:
    client.delete_collection("multimodal_rag")
except:
    pass

collection = client.create_collection("multimodal_rag")

# %%
import fitz  # PyMuPDF
import io
from PIL import Image
import chromadb
import google.generativeai as genai

# =========================================================
# 1. Configure Gemini API
# =========================================================
genai.configure(api_key="")

# Fast multimodal summarization
indexing_model = genai.GenerativeModel("gemini-2.5-flash")

# Strong reasoning over retrieved pages
reasoning_model = genai.GenerativeModel("gemini-2.5-flash")

# =========================================================
# 2. PDF → Images (IN MEMORY, NO FILE SYSTEM)
# =========================================================
def pdf_to_images_in_memory(pdf_path, zoom=2):
    """
    Converts PDF pages to PIL Images in memory.
    No disk writes → no Windows permission errors.
    """
    doc = fitz.open(pdf_path)
    images = []

    for page in doc:
        pix = page.get_pixmap(matrix=fitz.Matrix(zoom, zoom))
        img_bytes = pix.tobytes("png")
        img = Image.open(io.BytesIO(img_bytes)).convert("RGB")
        images.append(img)

    doc.close()
    return images

# =========================================================
# 3. Generate visual summaries for each page
# =========================================================
def generate_page_summaries(images):
    summaries = []
    print("🔍 Generating visual summaries for indexing...")

    for idx, img in enumerate(images):
        prompt = (
            "Describe this document page in detail. "
            "Focus on titles, headers, charts, tables, "
            "and important numeric or textual data."
        )

        response = indexing_model.generate_content([prompt, img])
        summaries.append(response.text)

        print(f"✅ Page {idx} summarized")

    return summaries

# =========================================================
# 4. Create Chroma Vector Store
# =========================================================
def create_vector_store(summaries):
    client = chromadb.Client()
    collection = client.create_collection(
        name="multimodal_rag",
        get_or_create=True
    )

    for i, summary in enumerate(summaries):
        collection.add(
            documents=[summary],
            metadatas=[{"page": i}],
            ids=[f"page_{i}"]
        )

    return collection


# =========================================================
# 5. Multimodal RAG Query
# =========================================================
def query_multimodal_rag(query, collection, images, top_k=2):
    results = collection.query(
        query_texts=[query],
        n_results=top_k
    )

    page_indices = [m["page"] for m in results["metadatas"][0]]
    retrieved_images = [images[i] for i in page_indices]
    context_text = "\n".join(results["documents"][0])

    prompt = f"""
User Question:
{query}

Context from Retrieved Page Summaries:
{context_text}

Instructions:
Use the attached document page images to answer precisely.
Carefully interpret any charts, tables, or numerical values.
"""

    response = reasoning_model.generate_content(
        [prompt, *retrieved_images]
    )

    return response.text, page_indices

# =========================================================
# 6. MAIN EXECUTION
# =========================================================
if __name__ == "__main__":
    PDF_FILE = "your_report.pdf"  # <-- Your PDF file

    # Step 1: Convert PDF → Images
    images = pdf_to_images_in_memory(PDF_FILE)

    # Step 2: Generate page summaries
    summaries = generate_page_summaries(images)

    # Step 3: Create vector database
    vector_db = create_vector_store(summaries)

    # Step 4: Ask a question
    user_query = "What does the chart say about the year-over-year revenue growth?"

    answer, pages_used = query_multimodal_rag(
        user_query,
        vector_db,
        images
    )

    print("\n================ AI ANSWER ================\n")
    print(answer)

    print("\n============ PAGES USED ============\n")
    print(pages_used)
# Out:
# 🔍 Generating visual summaries for indexing...
# ✅ Page 0 summarized
# ✅ Page 1 summarized
# ✅ Page 2 summarized
#
# ================ AI ANSWER ================
#
# The chart (presented as a table) shows that year-over-year revenue growth accelerated:
# *   In **2023**, revenue grew by **+30%**.
# *   In **2024**, revenue grew by **+35%**, which was the highest increase and showed a strong upward trend.
#
# ============ PAGES USED ============
#
# [1, 2]

# %%
pip install reportlab
# Out:
# Collecting reportlab
#   Downloading reportlab-4.4.7-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from reportlab) (11.0.0)
# Requirement already satisfied: charset-normalizer in c:\users\nikhil\appdata\local\programs\python\python311\lib\site-packages (from reportlab) (3.4.4)
# Downloading reportlab-4.4.7-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------------------- ------- 1.6/2.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 7.8 MB/s  0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from reportlab.lib.pagesizes import A4
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch

def create_dummy_pdf(filename="your_report.pdf"):
    c = canvas.Canvas(filename, pagesize=A4)
    width, height = A4

    # -------- Page 1 --------
    c.setFont("Helvetica-Bold", 18)
    c.drawString(1 * inch, height - 1 * inch, "Annual Revenue Report 2024")

    c.setFont("Helvetica", 12)
    c.drawString(1 * inch, height - 1.6 * inch, "Company: ABC Technologies")
    c.drawString(1 * inch, height - 2.0 * inch, "Prepared by: Finance Department")

    c.setFont("Helvetica", 11)
    c.drawString(1 * inch, height - 2.8 * inch,
                 "This report summarizes the year-over-year revenue growth.")
    
    c.drawString(1 * inch, height - 3.2 * inch,
                 "Overall revenue increased significantly compared to 2023.")

    c.showPage()

    # -------- Page 2 (Chart/Table Simulation) --------
    c.setFont("Helvetica-Bold", 16)
    c.drawString(1 * inch, height - 1 * inch, "Year-over-Year Revenue Growth")

    c.setFont("Helvetica-Bold", 12)
    c.drawString(1 * inch, height - 1.8 * inch, "Year")
    c.drawString(3 * inch, height - 1.8 * inch, "Revenue (USD)")
    c.drawString(5 * inch, height - 1.8 * inch, "Growth")

    c.setFont("Helvetica", 12)
    rows = [
        ("2022", "$2.0M", "-"),
        ("2023", "$2.6M", "+30%"),
        ("2024", "$3.5M", "+35%"),
    ]

    y = height - 2.4 * inch
    for year, revenue, growth in rows:
        c.drawString(1 * inch, y, year)
        c.drawString(3 * inch, y, revenue)
        c.drawString(5 * inch, y, growth)
        y -= 0.5 * inch

    c.drawString(
        1 * inch, y - 0.5 * inch,
        "The chart shows a strong upward trend with 35% growth in 2024."
    )

    c.showPage()

    # -------- Page 3 --------
    c.setFont("Helvetica-Bold", 16)
    c.drawString(1 * inch, height - 1 * inch, "Key Insights")

    c.setFont("Helvetica", 12)
    c.drawString(1 * inch, height - 1.8 * inch,
                 "• Revenue growth accelerated year-over-year.")
    c.drawString(1 * inch, height - 2.2 * inch,
                 "• 2024 saw the highest increase at 35%.")
    c.drawString(1 * inch, height - 2.6 * inch,
                 "• Growth driven by new enterprise clients.")

    c.save()
    print(f"Dummy PDF created: {filename}")

if __name__ == "__main__":
    create_dummy_pdf()
# Out:
# Dummy PDF created: your_report.pdf

# %%
import streamlit as st
import os
import fitz
import google.generativeai as genai
from PIL import Image
import chromadb

# --- CONFIGURATION ---
st.set_page_config(page_title="Gemini Multimodal RAG", layout="wide")
st.title("📄 Smart Research Assistant")
st.subheader("Analyze Text, Tables, and Charts using Gemini 1.5 Pro")

# Sidebar for API Key
with st.sidebar:
    api_key = st.text_input("Enter Google AI Studio API Key", type="password")
    if api_key:
        genai.configure(api_key=api_key)
        indexing_model = genai.GenerativeModel('gemini-1.5-flash')
        reasoning_model = genai.GenerativeModel('gemini-1.5-pro')

# --- HELPER FUNCTIONS ---
def get_pdf_images(uploaded_file):
    doc = fitz.open(stream=uploaded_file.read(), filetype="pdf")
    image_paths = []
    if not os.path.exists("temp_images"):
        os.makedirs("temp_images")
    
    for i in range(len(doc)):
        page = doc.load_page(i)
        pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
        path = f"temp_images/page_{i}.png"
        pix.save(path)
        image_paths.append(path)
    return image_paths

# --- UI LOGIC ---
uploaded_file = st.file_uploader("Upload a complex PDF (Financial reports, Research papers)", type="pdf")

if uploaded_file and api_key:
    if 'vector_db' not in st.session_state:
        with st.status("Processing Document..."):
            # 1. Convert PDF to Images
            img_paths = get_pdf_images(uploaded_file)
            
            # 2. Indexing (Generating Summaries)
            summaries = []
            for path in img_paths:
                img = Image.open(path)
                res = indexing_model.generate_content(["Summarize this page accurately for a search engine.", img])
                summaries.append(res.text)
            
            # 3. Store in ChromaDB
            client = chromadb.Client()
            collection = client.create_collection(name=f"col_{uploaded_file.name[:5]}")
            for i, s in enumerate(summaries):
                collection.add(documents=[s], metadatas=[{"path": img_paths[i]}], ids=[str(i)])
            
            st.session_state.vector_db = collection
            st.success("Document Indexed!")

    # --- CHAT INTERFACE ---
    query = st.chat_input("Ask about a chart, table, or specific data...")
    
    if query:
        with st.chat_message("user"):
            st.write(query)
        
        with st.chat_message("assistant"):
            # Retrieval
            results = st.session_state.vector_db.query(query_texts=[query], n_results=1)
            best_page_path = results['metadatas'][0][0]['path']
            
            # Generation
            img_to_analyze = Image.open(best_page_path)
            prompt = f"Using the provided document image, answer: {query}"
            response = reasoning_model.generate_content([prompt, img_to_analyze])
            
            # Display result
            st.write(response.text)
            st.divider()
            st.caption("Reference Page Used:")
            st.image(img_to_analyze, width=400)

elif not api_key:
    st.info("Please enter your API key in the sidebar to begin.")
# Out:
# 2025-12-31 17:27:01.472 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.473 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.808
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\NIKHIL\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-31 17:27:01.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.813 Session state does not function when running a script without `streamlit run`
# 2025-12-31 17:27:01.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-31 17:27:01.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
